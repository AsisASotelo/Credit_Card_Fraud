# %% [markdown]
# # Initial Data Exploration

# %% [markdown]
# The purpose of this notebook is to assess data quality of the data located in the "creditcard".csv

# %% [markdown]
# ### Content Of Dataset

# %% [markdown]
# The data contains credit card transaction data from September 2013. It contains data that occured in the span of two days and contains 492 fraudulent entries and a total of 284,807 transactions. About .172 % of the data is fraudelant. This means that the dataset is **unbalanced**. Certain actions must be taken and specific models will be used keeping this in mind. Couple of things to note from others who have done models on this.
#
# * Do not test models on oversampled or undersampled data
# * If you want to implement cross validation, oversample and undersample during cross validation
# * Don't use accuracy score for anamoly detection us f1, precision/recall, or confusion matrix
#
# A couple of things to note about the features:
# * The data has had PCA performed on it from V1-V28 so we assume that it has been scaled
# *

# %%
#Imports 

import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import numpy as np
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20190906212232-0000
# KERNEL_ID = 6783e9b2-5aff-4734-8474-969737b9ffef

# %% [markdown]
# NOTE: Do cross validation before going into feature sampling

# %% [markdown]
# ### We import the dataset into a pandas dataframe

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# We see that we have two untransformed columns **"Time"** and **"Amount"** as well as our target variable **class**.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df.isnull().sum().max()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
corr = df.corr()

# %% [markdown]
# The following are the attributes of the dataset:
#   * We have **284,807** total entries
#   * All columns are of type float
#   * We have 31 columns **"Time"**, **"V1"-"V28"**, **"Amount"**, and **"Class"**.

# %% [markdown]
# We will now try to visualize some of the data first the distribution of the data

# %%
time_dist = df['Time']
sns.distplot(time_dist)
plt.show()

# %%
sns.heatmap(corr)

# %% [markdown]
# Check counts of data

# %%
check = df['Class'].value_counts().to_frame().reset_index()
check['percent'] = check['Class'].apply(lambda x: 100*x/(len(df)))
check
# Out:
#    index   Class    percent
# 0      0  284315  99.827251
# 1      1     492   0.172749

# %%
scaler = MinMaxScaler()

# %%
df[['Time', 'Amount']] = scaler.fit_transform(df[['Time', 'Amount']])

# %%
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  0.000000 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1  0.000000  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2  0.000006 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3  0.000006 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4  0.000012 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
corr_scaled = df.corr()

# %%
sns.heatmap(corr)

# %%
sns.boxplot(df['Amount'])
